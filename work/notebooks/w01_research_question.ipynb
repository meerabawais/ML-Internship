# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/meerabawais/ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I have selected Lane 2: Refresh / Content Opportunit because it focuses on helping prioritize which content pages should be reviewed first for improvement. Rather than attempting to automatically improve content, the goal is to create an evidence-based ranking that helps reviewers spend their limited time on the pages with the greatest opportunity. This lane is well supported by the starter dataset and allows me to begin with transparent baseline methods before exploring machine learning models in later weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# #Search Question
# Which content pages should be reviewed first for refresh, expansion, monitoring, or improvement based on observable search and engagement signals?
# #Decision
# The decision is determining which pages should receive review before others.
# #Action
# A content reviewer can inspect the highest-ranked pages first and decide whether to refresh, expand, improve metadata, or continue monitoring them.
# #Cost of a Wrong Recommendation
# If a page is incorrectly ranked too high (false positive), reviewers may waste valuable time reviewing pages with little improvement potential.If an important page is ranked too low (false negative), valuable opportunities for improving traffic and engagement may be missed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd
from google.colab import files
uploaded = files.upload()
df = pd.read_csv("content_refresh_anonymized.csv")
print("Dataset Shape:", df.shape)
print("\nTrend Direction")
print(df["trend_direction"].value_counts())
print("\nAverage 90-Day Impressions")
print(df["impressions_90d"].mean())
print("\nAverage 90-Day Sessions")
print(df["sessions_90d"].mean())
# Out:
#      <input type="file" id="files-f97e83e4-9d91-45b4-8b4c-5e42e6ea5e91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f97e83e4-9d91-45b4-8b4c-5e42e6ea5e91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project is intended to support content review decisions by identifying pages that appear to have stronger refresh opportunities based on observable search and engagement signals.
# The results can identify patterns and associations in the available data and produce a ranked list of pages that may deserve review. These recommendations are intended to help prioritize human effort rather than replace human judgment.
# However, this project cannot prove that refreshing a page will increase traffic or engagement, nor can it determine Google's ranking factors or predict future search algorithm changes. Any recommendations should be interpreted as decision-support based on historical observations rather than causal evidence.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
